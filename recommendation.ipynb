# %%
#importing libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#path to dataset
dataset_path = '/content/dataset.csv'

# loading the csv into a dataframe
df = pd.read_csv(dataset_path)

df.head()
# Out:
#    Release Year                   Title Origin/Ethnicity          Director  \
# 0          2001            Another Life          British    Philip Goodhew
# 1          2010  Jalachhayam (ജലച്ചായം)        Malayalam  Sathish Kalathil
# 2          1958    Run Silent, Run Deep         American       Robert Wise
# 3          1948  Scott of the Antarctic          British     Charles Frend
# 4          1996          Romeo + Juliet         American      Baz Luhrmann
#
#                                                 Cast  \
# 0                      Ioan Gruffudd, Natasha Little
# 1  Baburaj Puthoor, Dr. B Jayakrishnan, Prasanna ...
# 2  Clark Gable, Burt Lancaster, Jack Warden, Brad...
# 3   John Mills, James Robertson Justice, Barry Letts
# 4  Leonardo DiCaprio, Claire Danes, Brian Dennehy...
#
#                          Genre  \
# 0                        drama
# 1  experimental film, art film
# 2                          war
# 3             adventure/biopic
# 4               romantic drama
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Another_Life_(20...
# 1          https://en.wikipedia.org/wiki/Jalachhayam
# 2  https://en.wikipedia.org/wiki/Run_Silent,_Run_...
# 3  https://en.wikipedia.org/wiki/Scott_of_the_Ant...
# 4     https://en.wikipedia.org/wiki/Romeo_%2B_Juliet
#
#                                                 Plot
# 0  Chiefly set in London during the First World W...
# 1  Mohan, an art teacher at a city college, disco...
# 2  A World War II US Navy submarine officer, Comm...
# 3  Captain Scott is given the men, but not the fu...
# 4  In Verona Beach, the Capulets and the Montague...

# %%
df.shape
# Out:
# (10000, 8)

# %%
# selecting random rows from df
df = df.sample(500, random_state=42)
df.head()
# Out:
#       Release Year              Title Origin/Ethnicity         Director  \
# 6252          2013      Shadow People         American   Matthew Arnold
# 4684          2000           Platform          Chinese      Jia Zhangke
# 1731          1931  The Miracle Woman         American      Frank Capra
# 4742          1995       Muthu Kaalai            Tamil  Gokula Krishnan
# 4521          2009           Triangle     South_Korean          Unknown
#
#                                                    Cast    Genre  \
# 6252  Dallas Roberts, Alison Eastwood, Anne Dudek, M...   horror
# 4684                           Zhao Tao\r\nWang Hongwei    drama
# 1731         Barbara Stanwyck, David Manners, Sam Hardy    drama
# 4742                                 Karthik, Soundarya  unknown
# 4521                                       Ji Yeong-soo  unknown
#
#                                               Wiki Page  \
# 6252  https://en.wikipedia.org/wiki/Shadow_People_(f...
# 4684  https://en.wikipedia.org/wiki/Platform_(2000_f...
# 1731    https://en.wikipedia.org/wiki/The_Miracle_Woman
# 4742         https://en.wikipedia.org/wiki/Muthu_Kaalai
# 4521  https://en.wikipedia.org/wiki/Triangle_(2009_S...
#
#                                                    Plot
# 6252  The film begins with a series of videos posted...
# 4684  The film starts in 1979 in the wake of the Cul...
# 1731  Florence Fallon is outraged when church elders...
# 4742  The film begins with Poochi (Vadivelu) announc...
# 4521  Ji-young is a beautiful widow of an extremely ...

# %%
# filling missing values in 'Plot', 'Title', and 'Genre' columns with empty strings
df['Plot'] = df['Plot'].fillna('')
df['Title'] = df['Title'].fillna('')
df['Genre'] = df['Genre'].fillna('')

# combining 'Title', 'Genre', and 'Plot' into a single "metadata" column
df['Metadata'] = df['Title'] + ' ' + df['Genre'] + ' ' + df['Plot']

df[['Title', 'Genre', 'Metadata']].head()
# Out:
#                   Title    Genre  \
# 6252      Shadow People   horror
# 4684           Platform    drama
# 1731  The Miracle Woman    drama
# 4742       Muthu Kaalai  unknown
# 4521           Triangle  unknown
#
#                                                Metadata
# 6252  Shadow People horror The film begins with a se...
# 4684  Platform drama The film starts in 1979 in the ...
# 1731  The Miracle Woman drama Florence Fallon is out...
# 4742  Muthu Kaalai unknown The film begins with Pooc...
# 4521  Triangle unknown Ji-young is a beautiful widow...

# %%
# initializing the TF-IDF vectorizer using english
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# transform the metadata into TF-IDF features
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Metadata'])

# checking the shape of the matrix to ensure it matches the number of movies
print("TF-IDF matrix shape:", tfidf_matrix.shape)
# Out:
# TF-IDF matrix shape: (500, 16802)

# %%
 #recommends movies based on user query by computing cosine similarity b/w the query and the "metadata"
 #parameters :
        #  query (str): The user's description of movie preferences.
        # tfidf_matrix: TF-IDF matrix of all movie metadata.
        # df (DataFrame): The movies dataframe.
        # top_n (int): The number of top recommendations to return.
 #returns a dataframe containing movie title and similarity score

def recommend_movies(query, tfidf_matrix, df, top_n=5):
    #transforming the user's query into the TF-IDF space
    query_vec = tfidf_vectorizer.transform([query])

    #computing cosine similarity between the query and all movie metadata
    cosine_sim = cosine_similarity(query_vec, tfidf_matrix).flatten()

    #getting indices of movies with highest similarity scores
    top_indices = cosine_sim.argsort()[-top_n:][::-1]

    #preparing a df with the recommended movies
    recommendations = df.iloc[top_indices][['Title']].copy()
    recommendations['Similarity'] = cosine_sim[top_indices]
    return recommendations

# %%
# prompt the user for their input query
user_query = input("What kind of movies do you want to watch? ")

# generacte and print top recommendations based on user input
recommended_movies = recommend_movies(user_query, tfidf_matrix, df, top_n=5)
print("Top Recommendations:")
print(recommended_movies)
# Out:
# What kind of movies do you want to watch? I want to watch a forest adventure movie with comedy elements
# Top Recommendations:
#                                                   Title  Similarity
# 3238                      The Jones Family in Hollywood    0.116647
# 5572                                    Drums of Africa    0.113227
# 2592  Poketto Monsutā Serebii: The Meeting that Trav...    0.093716
# 2232                                          The Watch    0.093385
# 333                                               Aaaah    0.076098
